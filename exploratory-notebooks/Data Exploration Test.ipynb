# %% [markdown]
# # Librairies and set up

# %%
#pip install os
import os 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
os.getcwd()
# Out:
# '/Users/Armand/Capstone/privacy-preserving-analytics/exploratory-notebooks'

# %%
os.chdir('/Users/Armand/Capstone/ipinyou.contest.dataset/testing2nd')

# %%
header_season2=[
    'Bid ID'
    ,'Timestamp'
    ,'Log Type'
    ,'iPinYou ID'
    ,'User-Agent'
    ,'IP'
    ,'Region ID'
    ,'City ID'
    ,'Ad Exchange'
    ,'Domain'
    ,'URL'
    ,'Anonymous URL'
    ,'Ad Slot ID'
    ,'Ad Slot Width'
    ,'Ad Slot Height'
    ,'Ad Slot Visibility'
    ,'Ad Slot Format'
    ,'Ad Slot Floor Price'
    ,'Creative ID'
    ,'Bidding Price'
    ,'Paying Price'
    ,'Landing Page URL'
    ,'Advertiser ID'
    ,'User Profile IDs'
    ,'Relate Clicks'
    , 'if has conv']

# %%
df=pd.read_table('leaderboard.test.data.20130613_15.txt', names=header_season2)

# %%
df.head()
# Out:
#                              Bid ID          Timestamp  Log Type  \
# 0  82aed71bea7358c9a5be868deae30be0  20130613000101373         1
# 1  77c5c149c234a0de420eefe9b6e16517  20130613000101391         1
# 2  a45fe947ffb7a52f452308bb50b4a572  20130613000101428         1
# 3    184d6f9a71c3c53336cff407e5b7ae  20130613000101438         1
# 4  11415ce7ca9c7e1950b41bf3468fb288  20130613000101456         1
#
#         iPinYou ID  \
# 0  Vh5KZAnrPQTPJIC
# 1  Vh1HP3FpOUx6kgL
# 2  Vh5zPuc9DvT2lGk
# 3  Vh5KZAnrPoddkMf
# 4  VhdiPkNq3QNvwQL
#
#                                                                                                              User-Agent  \
# 0  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.802.30 Safari/535.1 SE 2.X MetaSr 1.0
# 1                   Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.89 Safari/537.1
# ...

# %%
print(df['Relate Clicks'].unique())
print(df['if has conv'].unique())
# Out:
# [0 1 2 6 4 5 3 8 7]
# [0 1]

# %%
df['Log Type'].unique()
# Out:
# array([1])

# %%
df.shape
# Out:
# (2521630, 26)
